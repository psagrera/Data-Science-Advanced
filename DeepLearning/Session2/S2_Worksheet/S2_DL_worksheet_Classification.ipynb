# %% [markdown]
# <a href="https://colab.research.google.com/github/psagrera/Data-Science-Advanced/blob/main/DeepLearning/Session2/S2_Worksheet/S2_DL_worksheet_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1zWG2FYCrmlZ8HmPjmgoIZikGW9MbrxMl" style="height: 100px">
# <center style="color:#888">Módulo Data Science in IoT<br/>Asignatura Deep Learning</center>
#
# # Worksheet S2: Clasificación con TensorFlow

# %% [markdown]
# ## Objetivos
#
# El objetivo de este worksheet es familiarizarnos con TensorFlow mediante un primer ejemplo basado en clasificación.
#
#
#
# ## Introducción

# %% [markdown]
# ### Clasificación
#
# En este worksheet vamos a tratar con nuestro primer problema de clasificación en TensorFlow. Mientras que en regresión lo que intentamos era predecir un valor numérico, en clasificación intentamos separar nuestros datos en distintas clases conocidas. En este ejemplo vamos a utilizar un estimador de TensorFlow para clasificar flores.

# %%
import tensorflow as tf

import pandas as pd

# %% [markdown]
# ### Dataset
#
# El dataset que vamos a utilizar contiene 3 clases distintas:
# - Setosa
# - Versicolor
# - Virginica
#
# De cada flor, se cuenta con la siguiente información:
#
# - Longitud del sépalo
# - Anchura del sépalo
# - Longitud del pétalo
# - Anchura del pétalo
#
# Vamos a definir estas constantes para utilizarlas posteriormente:

# %%
CSV_COLUMN_NAMES = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']
SPECIES = ['Setosa', 'Versicolor', 'Virginica']

# %% [markdown]
# El dataset que vamos a utilizar está preparado en el módulo de Keras para poder ser utilizado con facilidad, podemos cargarlo así:

# %%
train_path = tf.keras.utils.get_file(
    "iris_training.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv")
test_path = tf.keras.utils.get_file(
    "iris_test.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv")

train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
test = pd.read_csv(test_path, names=CSV_COLUMN_NAMES, header=0)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv
# 8192/2194 [================================================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv
# 8192/573 [============================================================================================================================================================================================================================================================================================================================================================================================================================================] - 0s 0us/step

# %% [markdown]
# Como siempre, comenzamos echando un vistazo a los datos:

# %%
train.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 0          6.4         2.8          5.6         2.2        2
# 1          5.0         2.3          3.3         1.0        1
# 2          4.9         2.5          4.5         1.7        2
# 3          4.9         3.1          1.5         0.1        0
# 4          5.7         3.8          1.7         0.3        0

# %% [markdown]
# A continuación vamos a retirar la columna "Especie" y la utilizaremos como etiqueta:

# %%
train_y = train.pop('Species')
test_y = test.pop('Species')
train.head() # como podemos ver, la especie ya no aparece
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth
# 0          6.4         2.8          5.6         2.2
# 1          5.0         2.3          3.3         1.0
# 2          4.9         2.5          4.5         1.7
# 3          4.9         3.1          1.5         0.1
# 4          5.7         3.8          1.7         0.3

# %%
train.shape
# Out:
# (120, 4)

# %% [markdown]
# ### Input Function
#
# Al igual que hicimos en nuestro ejemplo de regresión, necesitamos una input function. Por suerte, esta es más sencilla que la anterior :)

# %%
def input_fn(features, labels, training=True, batch_size=256):
    # Convertimos los datos al tipo dataset.
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))

    # Aleatorizamos y seleccionamos los datos si estamos en modo train.
    if training:
        dataset = dataset.shuffle(1000).repeat()
    
    return dataset.batch(batch_size)

# %% [markdown]
# ### Feature Columns
#
# Y de nuevo, necesitamos nuestros feature columns

# %%
# Feature columns describe cómo se utilizan las feature columns
my_feature_columns = []
for key in train.keys():
    my_feature_columns.append(tf.feature_column.numeric_column(key=key))
print(my_feature_columns)
# Out:
# [NumericColumn(key='SepalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='SepalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='PetalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='PetalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %% [markdown]
# ### Construyendo el Modelo
#
# Lo siguiente que tenemos que hacer es elegir el modelo. Para resolver un problema de clasificación de este tipo hay diferentes estimadores o modelos que podemos utilizar, por ejemplo:
#
# - Clasificador DNN (Deep Neural Network)
# - Clasificador Lineal
#
# Vamos a utilizar el estimador basado en una red neuronal, ya que no podemos asumir que haya una correspondencia lineal en nuestro dataset.
#
# Vamos a ello:

# %%
# Definimos una DNN con 2 capas ocultas con 30 y 10 nodos ocultos cada una.
classifier = tf.estimator.DNNClassifier(
    feature_columns=my_feature_columns,
    # Dos capas ocultas de 30 y 10 nodos respectivamente
    hidden_units=[30,10],
    # El modelo debe poder distinguir entre 3 clases
    n_classes=3)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/01/4d70j3nn55z71b4011q5p56r0000gn/T/tmp21oq8rrp
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/01/4d70j3nn55z71b4011q5p56r0000gn/T/tmp21oq8rrp', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# Como hemos comentado previamente, el número de capas y neuronas ocultas es un número arbitrario y necesitamos de muchos experimentos y test para poder determinar la mejor elección de estos valores.

# %% [markdown]
# ### Training
#
# Vamos a entrenar nuestra primera red neuronal

# %%
classifier.train(
    input_fn=lambda: input_fn(train, train_y, training=True),
    steps=40000)
# Hemos definido lambda para evitar crear una función previamente (los detalles de implementación no son importantes ahora)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/01/4d70j3nn55z71b4011q5p56r0000gn/T/tmp21oq8rrp/model.ckpt-5000
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/training/saver.py:1076: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into /var/folders/01/4d70j3nn55z71b4011q5p56r0000gn/T/tmp21oq8rrp/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:loss = 0.7072174, step = 5000
# INFO:tensorflow:global_step/sec: 499.206
# INFO:tensorflow:loss = 0.71547776, step = 5100 (0.201 sec)
# INFO:tensorflow:global_step/sec: 646.914
# INFO:tensorflow:loss = 0.7099789, step = 5200 (0.155 sec)
# INFO:tensorflow:global_step/sec: 647.895
# INFO:tensorflow:loss = 0.6987586, step = 5300 (0.155 sec)
# INFO:tensorflow:global_step/sec: 646.317
# INFO:tensorflow:loss = 0.697299, step = 5400 (0.155 sec)
# INFO:tensorflow:global_step/sec: 648.197
# INFO:tensorflow:loss = 0.6936929, step = 5500 (0.154 sec)
# INFO:tensorflow:global_step/sec: 648.239
# INFO:tensorflow:loss = 0.6967217, step = 5600 (0.154 sec)
# INFO:tensorflow:global_step/sec: 650.076
# INFO:tensorflow:loss = 0.68692297, step = 5700 (0.154 sec)
# INFO:tensorflow:global_step/sec: 630.665
# INFO:tensorflow:loss = 0.6845138, step = 5800 (0.158 sec)
# INFO:tensorflow:global_step/sec: 645.415
# INFO:tensorflow:loss = 0.68369603, step = 5900 (0.155 sec)
# INFO:tensorflow:global_step/sec: 618.575
# INFO:tensorflow:loss = 0.6894969, step = 6000 (0.162 sec)
# INFO:tensorflow:global_step/sec: 627.132
# INFO:tensorflow:loss = 0.6736294, step = 6100 (0.159 sec)
# INFO:tensorflow:global_step/sec: 645.22
# INFO:tensorflow:loss = 0.67577326, step = 6200 (0.155 sec)
# INFO:tensorflow:global_step/sec: 633.24
# INFO:tensorflow:loss = 0.67352843, step = 6300 (0.158 sec)
# INFO:tensorflow:global_step/sec: 628.12
# INFO:tensorflow:loss = 0.6726823, step = 6400 (0.159 sec)
# INFO:tensorflow:global_step/sec: 641.03
# INFO:tensorflow:loss = 0.67591256, step = 6500 (0.156 sec)
# INFO:tensorflow:global_step/sec: 426.999
# INFO:tensorflow:loss = 0.6738063, step = 6600 (0.235 sec)
# INFO:tensorflow:global_step/sec: 505.714
# INFO:tensorflow:loss = 0.67452925, step = 6700 (0.197 sec)
# INFO:tensorflow:global_step/sec: 628.528
# INFO:tensorflow:loss = 0.66659766, step = 6800 (0.159 sec)
# INFO:tensorflow:global_step/sec: 644.724
# INFO:tensorflow:loss = 0.66438556, step = 6900 (0.155 sec)
# INFO:tensorflow:global_step/sec: 645.095
# INFO:tensorflow:loss = 0.6618823, step = 7000 (0.155 sec)
# INFO:tensorflow:global_step/sec: 641.745
# INFO:tensorflow:loss = 0.66023123, step = 7100 (0.156 sec)
# INFO:tensorflow:global_step/sec: 646.221
# INFO:tensorflow:loss = 0.6650455, step = 7200 (0.155 sec)
# INFO:tensorflow:global_step/sec: 643.02
# INFO:tensorflow:loss = 0.66087854, step = 7300 (0.156 sec)
# INFO:tensorflow:global_step/sec: 644.451
# INFO:tensorflow:loss = 0.65327466, step = 7400 (0.155 sec)
# INFO:tensorflow:global_step/sec: 644.771
# INFO:tensorflow:loss = 0.6424453, step = 7500 (0.155 sec)
# INFO:tensorflow:global_step/sec: 640.241
# INFO:tensorflow:loss = 0.6552938, step = 7600 (0.156 sec)
# INFO:tensorflow:global_step/sec: 638.427
# INFO:tensorflow:loss = 0.6506442, step = 7700 (0.157 sec)
# INFO:tensorflow:global_step/sec: 640.3
# INFO:tensorflow:loss = 0.6415274, step = 7800 (0.156 sec)
# INFO:tensorflow:global_step/sec: 637.325
# INFO:tensorflow:loss = 0.64194024, step = 7900 (0.157 sec)
# INFO:tensorflow:global_step/sec: 643.445
# INFO:tensorflow:loss = 0.63696826, step = 8000 (0.155 sec)
# INFO:tensorflow:global_step/sec: 641.878
# INFO:tensorflow:loss = 0.64078546, step = 8100 (0.156 sec)
# INFO:tensorflow:global_step/sec: 640.816
# INFO:tensorflow:loss = 0.6387157, step = 8200 (0.156 sec)
# INFO:tensorflow:global_step/sec: 640.787
# INFO:tensorflow:loss = 0.6279928, step = 8300 (0.156 sec)
# INFO:tensorflow:global_step/sec: 634.526
# INFO:tensorflow:loss = 0.63000953, step = 8400 (0.158 sec)
# INFO:tensorflow:global_step/sec: 641.416
# INFO:tensorflow:loss = 0.62441397, step = 8500 (0.156 sec)
# INFO:tensorflow:global_step/sec: 635.821
# INFO:tensorflow:loss = 0.621454, step = 8600 (0.157 sec)
# INFO:tensorflow:global_step/sec: 632.984
# INFO:tensorflow:loss = 0.6233574, step = 8700 (0.158 sec)
# INFO:tensorflow:global_step/sec: 639.709
# INFO:tensorflow:loss = 0.63083434, step = 8800 (0.156 sec)
# INFO:tensorflow:global_step/sec: 634.948
# INFO:tensorflow:loss = 0.62068915, step = 8900 (0.158 sec)
# INFO:tensorflow:global_step/sec: 632.703
# INFO:tensorflow:loss = 0.62420595, step = 9000 (0.158 sec)
# INFO:tensorflow:global_step/sec: 607.936
# INFO:tensorflow:loss = 0.6259191, step = 9100 (0.165 sec)
# INFO:tensorflow:global_step/sec: 627.541
# INFO:tensorflow:loss = 0.6166856, step = 9200 (0.159 sec)
# INFO:tensorflow:global_step/sec: 564.197
# INFO:tensorflow:loss = 0.6175647, step = 9300 (0.177 sec)
# INFO:tensorflow:global_step/sec: 640.131
# INFO:tensorflow:loss = 0.6098564, step = 9400 (0.156 sec)
# INFO:tensorflow:global_step/sec: 630.851
# INFO:tensorflow:loss = 0.6089821, step = 9500 (0.159 sec)
# INFO:tensorflow:global_step/sec: 365.441
# INFO:tensorflow:loss = 0.6135572, step = 9600 (0.274 sec)
# INFO:tensorflow:global_step/sec: 371.375
# INFO:tensorflow:loss = 0.61229515, step = 9700 (0.269 sec)
# INFO:tensorflow:global_step/sec: 492.252
# INFO:tensorflow:loss = 0.602226, step = 9800 (0.203 sec)
# INFO:tensorflow:global_step/sec: 594.379
# INFO:tensorflow:loss = 0.6004283, step = 9900 (0.168 sec)
# INFO:tensorflow:global_step/sec: 634.265
# INFO:tensorflow:loss = 0.5932238, step = 10000 (0.158 sec)
# INFO:tensorflow:global_step/sec: 630.091
# INFO:tensorflow:loss = 0.6010074, step = 10100 (0.159 sec)
# INFO:tensorflow:global_step/sec: 618.77
# INFO:tensorflow:loss = 0.59906805, step = 10200 (0.161 sec)
# INFO:tensorflow:global_step/sec: 620.132
# INFO:tensorflow:loss = 0.60059863, step = 10300 (0.161 sec)
# INFO:tensorflow:global_step/sec: 626.967
# INFO:tensorflow:loss = 0.5939251, step = 10400 (0.160 sec)
# INFO:tensorflow:global_step/sec: 604.796
# INFO:tensorflow:loss = 0.581255, step = 10500 (0.165 sec)
# INFO:tensorflow:global_step/sec: 625.023
# INFO:tensorflow:loss = 0.5991873, step = 10600 (0.160 sec)
# INFO:tensorflow:global_step/sec: 588.776
# INFO:tensorflow:loss = 0.5959239, step = 10700 (0.170 sec)
# INFO:tensorflow:global_step/sec: 469.146
# INFO:tensorflow:loss = 0.5823993, step = 10800 (0.213 sec)
# INFO:tensorflow:global_step/sec: 488.271
# INFO:tensorflow:loss = 0.5845516, step = 10900 (0.205 sec)
# INFO:tensorflow:global_step/sec: 577.284
# INFO:tensorflow:loss = 0.58545125, step = 11000 (0.173 sec)
# INFO:tensorflow:global_step/sec: 637.009
# INFO:tensorflow:loss = 0.5887741, step = 11100 (0.157 sec)
# INFO:tensorflow:global_step/sec: 627.233
# INFO:tensorflow:loss = 0.572471, step = 11200 (0.159 sec)
# INFO:tensorflow:global_step/sec: 629.097
# INFO:tensorflow:loss = 0.57990867, step = 11300 (0.159 sec)
# INFO:tensorflow:global_step/sec: 639.689
# INFO:tensorflow:loss = 0.5689368, step = 11400 (0.156 sec)
# INFO:tensorflow:global_step/sec: 638.235
# INFO:tensorflow:loss = 0.57447845, step = 11500 (0.157 sec)
# INFO:tensorflow:global_step/sec: 630.962
# INFO:tensorflow:loss = 0.57103634, step = 11600 (0.158 sec)
# INFO:tensorflow:global_step/sec: 631.445
# INFO:tensorflow:loss = 0.5712154, step = 11700 (0.159 sec)
# INFO:tensorflow:global_step/sec: 631.513
# INFO:tensorflow:loss = 0.5701356, step = 11800 (0.158 sec)
# INFO:tensorflow:global_step/sec: 633.429
# INFO:tensorflow:loss = 0.5667213, step = 11900 (0.158 sec)
# INFO:tensorflow:global_step/sec: 628.843
# INFO:tensorflow:loss = 0.5726291, step = 12000 (0.159 sec)
# INFO:tensorflow:global_step/sec: 632.027
# INFO:tensorflow:loss = 0.57447195, step = 12100 (0.158 sec)
# INFO:tensorflow:global_step/sec: 633.245
# INFO:tensorflow:loss = 0.5650853, step = 12200 (0.158 sec)
# INFO:tensorflow:global_step/sec: 632.246
# INFO:tensorflow:loss = 0.5580758, step = 12300 (0.158 sec)
# INFO:tensorflow:global_step/sec: 622.162
# INFO:tensorflow:loss = 0.5691153, step = 12400 (0.161 sec)
# INFO:tensorflow:global_step/sec: 633.42
# INFO:tensorflow:loss = 0.55553794, step = 12500 (0.158 sec)
# INFO:tensorflow:global_step/sec: 629.521
# INFO:tensorflow:loss = 0.5449858, step = 12600 (0.159 sec)
# INFO:tensorflow:global_step/sec: 632.29
# INFO:tensorflow:loss = 0.56193537, step = 12700 (0.158 sec)
# INFO:tensorflow:global_step/sec: 567.985
# INFO:tensorflow:loss = 0.55576324, step = 12800 (0.176 sec)
# INFO:tensorflow:global_step/sec: 634.076
# INFO:tensorflow:loss = 0.5396881, step = 12900 (0.158 sec)
# INFO:tensorflow:global_step/sec: 633.18
# INFO:tensorflow:loss = 0.54667413, step = 13000 (0.158 sec)
# INFO:tensorflow:global_step/sec: 636.594
# INFO:tensorflow:loss = 0.5526259, step = 13100 (0.158 sec)
# INFO:tensorflow:global_step/sec: 623.795
# INFO:tensorflow:loss = 0.5434571, step = 13200 (0.160 sec)
# INFO:tensorflow:global_step/sec: 627.172
# INFO:tensorflow:loss = 0.5391263, step = 13300 (0.160 sec)
# INFO:tensorflow:global_step/sec: 628.816
# INFO:tensorflow:loss = 0.5450575, step = 13400 (0.159 sec)
# INFO:tensorflow:global_step/sec: 623.414
# INFO:tensorflow:loss = 0.52927953, step = 13500 (0.160 sec)
# INFO:tensorflow:global_step/sec: 631.649
# INFO:tensorflow:loss = 0.53862727, step = 13600 (0.158 sec)
# INFO:tensorflow:global_step/sec: 631.74
# INFO:tensorflow:loss = 0.5352378, step = 13700 (0.158 sec)
# INFO:tensorflow:global_step/sec: 626.068
# INFO:tensorflow:loss = 0.53062457, step = 13800 (0.160 sec)
# INFO:tensorflow:global_step/sec: 472.389
# INFO:tensorflow:loss = 0.53247523, step = 13900 (0.213 sec)
# INFO:tensorflow:global_step/sec: 364.949
# INFO:tensorflow:loss = 0.529416, step = 14000 (0.274 sec)
# INFO:tensorflow:global_step/sec: 406.246
# INFO:tensorflow:loss = 0.52868736, step = 14100 (0.247 sec)
# INFO:tensorflow:global_step/sec: 343.86
# INFO:tensorflow:loss = 0.5295739, step = 14200 (0.290 sec)
# INFO:tensorflow:global_step/sec: 376.189
# INFO:tensorflow:loss = 0.52336806, step = 14300 (0.265 sec)
# INFO:tensorflow:global_step/sec: 477.272
# INFO:tensorflow:loss = 0.5171719, step = 14400 (0.210 sec)
# INFO:tensorflow:global_step/sec: 427.297
# INFO:tensorflow:loss = 0.51748884, step = 14500 (0.234 sec)
# INFO:tensorflow:global_step/sec: 399.798
# INFO:tensorflow:loss = 0.518401, step = 14600 (0.251 sec)
# INFO:tensorflow:global_step/sec: 439.97
# INFO:tensorflow:loss = 0.5131285, step = 14700 (0.226 sec)
# INFO:tensorflow:global_step/sec: 602.305
# INFO:tensorflow:loss = 0.5139229, step = 14800 (0.166 sec)
# INFO:tensorflow:global_step/sec: 617.595
# INFO:tensorflow:loss = 0.51584977, step = 14900 (0.162 sec)
# INFO:tensorflow:global_step/sec: 620.326
# INFO:tensorflow:loss = 0.5058727, step = 15000 (0.161 sec)
# INFO:tensorflow:global_step/sec: 623.666
# INFO:tensorflow:loss = 0.5115912, step = 15100 (0.160 sec)
# INFO:tensorflow:global_step/sec: 613.942
# INFO:tensorflow:loss = 0.5114951, step = 15200 (0.163 sec)
# INFO:tensorflow:global_step/sec: 615.93
# INFO:tensorflow:loss = 0.5101143, step = 15300 (0.163 sec)
# INFO:tensorflow:global_step/sec: 615.937
# INFO:tensorflow:loss = 0.5132624, step = 15400 (0.162 sec)
# INFO:tensorflow:global_step/sec: 602.926
# INFO:tensorflow:loss = 0.5106763, step = 15500 (0.166 sec)
# INFO:tensorflow:global_step/sec: 537.481
# INFO:tensorflow:loss = 0.4952613, step = 15600 (0.186 sec)
# INFO:tensorflow:global_step/sec: 393.21
# INFO:tensorflow:loss = 0.49231955, step = 15700 (0.254 sec)
# INFO:tensorflow:global_step/sec: 630.24
# INFO:tensorflow:loss = 0.50001395, step = 15800 (0.159 sec)
# INFO:tensorflow:global_step/sec: 647.277
# INFO:tensorflow:loss = 0.49305105, step = 15900 (0.155 sec)
# INFO:tensorflow:global_step/sec: 643.916
# INFO:tensorflow:loss = 0.49477768, step = 16000 (0.155 sec)
# INFO:tensorflow:global_step/sec: 642.668
# INFO:tensorflow:loss = 0.49778426, step = 16100 (0.156 sec)
# INFO:tensorflow:global_step/sec: 633.352
# INFO:tensorflow:loss = 0.4916977, step = 16200 (0.158 sec)
# INFO:tensorflow:global_step/sec: 638.378
# INFO:tensorflow:loss = 0.4949382, step = 16300 (0.157 sec)
# INFO:tensorflow:global_step/sec: 626.402
# INFO:tensorflow:loss = 0.49081993, step = 16400 (0.160 sec)
# INFO:tensorflow:global_step/sec: 639.219
# INFO:tensorflow:loss = 0.48429632, step = 16500 (0.156 sec)
# INFO:tensorflow:global_step/sec: 628.319
# INFO:tensorflow:loss = 0.4834711, step = 16600 (0.159 sec)
# INFO:tensorflow:global_step/sec: 638.512
# INFO:tensorflow:loss = 0.48134366, step = 16700 (0.156 sec)
# INFO:tensorflow:global_step/sec: 641.017
# INFO:tensorflow:loss = 0.47634417, step = 16800 (0.156 sec)
# INFO:tensorflow:global_step/sec: 640.213
# INFO:tensorflow:loss = 0.4816118, step = 16900 (0.156 sec)
# INFO:tensorflow:global_step/sec: 644.33
# INFO:tensorflow:loss = 0.4785396, step = 17000 (0.156 sec)
# INFO:tensorflow:global_step/sec: 632.38
# INFO:tensorflow:loss = 0.47667181, step = 17100 (0.158 sec)
# INFO:tensorflow:global_step/sec: 386.52
# INFO:tensorflow:loss = 0.47329822, step = 17200 (0.259 sec)
# INFO:tensorflow:global_step/sec: 504.019
# INFO:tensorflow:loss = 0.47234637, step = 17300 (0.198 sec)
# INFO:tensorflow:global_step/sec: 642.146
# INFO:tensorflow:loss = 0.47251183, step = 17400 (0.156 sec)
# INFO:tensorflow:global_step/sec: 649.823
# INFO:tensorflow:loss = 0.47307923, step = 17500 (0.154 sec)
# INFO:tensorflow:global_step/sec: 648.521
# INFO:tensorflow:loss = 0.4718515, step = 17600 (0.154 sec)
# INFO:tensorflow:global_step/sec: 643.923
# INFO:tensorflow:loss = 0.46432352, step = 17700 (0.155 sec)
# INFO:tensorflow:global_step/sec: 643.231
# INFO:tensorflow:loss = 0.46230304, step = 17800 (0.155 sec)
# INFO:tensorflow:global_step/sec: 644.651
# INFO:tensorflow:loss = 0.4614904, step = 17900 (0.155 sec)
# INFO:tensorflow:global_step/sec: 639.655
# INFO:tensorflow:loss = 0.46596336, step = 18000 (0.156 sec)
# INFO:tensorflow:global_step/sec: 629.659
# INFO:tensorflow:loss = 0.46680415, step = 18100 (0.159 sec)
# INFO:tensorflow:global_step/sec: 392.913
# INFO:tensorflow:loss = 0.45396268, step = 18200 (0.255 sec)
# INFO:tensorflow:global_step/sec: 495.89
# INFO:tensorflow:loss = 0.4559394, step = 18300 (0.202 sec)
# INFO:tensorflow:global_step/sec: 635.837
# INFO:tensorflow:loss = 0.45336953, step = 18400 (0.157 sec)
# INFO:tensorflow:global_step/sec: 646.475
# INFO:tensorflow:loss = 0.45188636, step = 18500 (0.155 sec)
# INFO:tensorflow:global_step/sec: 646.458
# INFO:tensorflow:loss = 0.4542523, step = 18600 (0.155 sec)
# INFO:tensorflow:global_step/sec: 642.393
# INFO:tensorflow:loss = 0.45304227, step = 18700 (0.156 sec)
# INFO:tensorflow:global_step/sec: 617.467
# INFO:tensorflow:loss = 0.44961113, step = 18800 (0.162 sec)
# INFO:tensorflow:global_step/sec: 640.241
# INFO:tensorflow:loss = 0.43909958, step = 18900 (0.156 sec)
# INFO:tensorflow:global_step/sec: 641.187
# INFO:tensorflow:loss = 0.4479512, step = 19000 (0.156 sec)
# INFO:tensorflow:global_step/sec: 646.342
# INFO:tensorflow:loss = 0.44306615, step = 19100 (0.155 sec)
# INFO:tensorflow:global_step/sec: 643.053
# INFO:tensorflow:loss = 0.44109973, step = 19200 (0.156 sec)
# INFO:tensorflow:global_step/sec: 641.097
# INFO:tensorflow:loss = 0.44003895, step = 19300 (0.156 sec)
# INFO:tensorflow:global_step/sec: 635.747
# INFO:tensorflow:loss = 0.43859228, step = 19400 (0.157 sec)
# INFO:tensorflow:global_step/sec: 639.795
# INFO:tensorflow:loss = 0.4423321, step = 19500 (0.156 sec)
# INFO:tensorflow:global_step/sec: 617.197
# INFO:tensorflow:loss = 0.43767932, step = 19600 (0.162 sec)
# INFO:tensorflow:global_step/sec: 628.781
# INFO:tensorflow:loss = 0.43498927, step = 19700 (0.159 sec)
# INFO:tensorflow:global_step/sec: 644.122
# INFO:tensorflow:loss = 0.4354089, step = 19800 (0.155 sec)
# INFO:tensorflow:global_step/sec: 637.873
# INFO:tensorflow:loss = 0.42775697, step = 19900 (0.157 sec)
# INFO:tensorflow:global_step/sec: 439.759
# INFO:tensorflow:loss = 0.42334372, step = 20000 (0.228 sec)
# INFO:tensorflow:global_step/sec: 372.484
# INFO:tensorflow:loss = 0.4282058, step = 20100 (0.268 sec)
# INFO:tensorflow:global_step/sec: 623.907
# INFO:tensorflow:loss = 0.42438048, step = 20200 (0.160 sec)
# INFO:tensorflow:global_step/sec: 639.816
# INFO:tensorflow:loss = 0.42423028, step = 20300 (0.156 sec)
# INFO:tensorflow:global_step/sec: 643.629
# INFO:tensorflow:loss = 0.42532983, step = 20400 (0.155 sec)
# INFO:tensorflow:global_step/sec: 648.555
# INFO:tensorflow:loss = 0.42503572, step = 20500 (0.154 sec)
# INFO:tensorflow:global_step/sec: 644.097
# INFO:tensorflow:loss = 0.41688776, step = 20600 (0.155 sec)
# INFO:tensorflow:global_step/sec: 645.632
# INFO:tensorflow:loss = 0.4178766, step = 20700 (0.155 sec)
# INFO:tensorflow:global_step/sec: 633.93
# INFO:tensorflow:loss = 0.41116297, step = 20800 (0.158 sec)
# INFO:tensorflow:global_step/sec: 497.795
# INFO:tensorflow:loss = 0.41368815, step = 20900 (0.201 sec)
# INFO:tensorflow:global_step/sec: 405.081
# INFO:tensorflow:loss = 0.41035688, step = 21000 (0.247 sec)
# INFO:tensorflow:global_step/sec: 621.288
# INFO:tensorflow:loss = 0.4101495, step = 21100 (0.161 sec)
# INFO:tensorflow:global_step/sec: 635.182
# INFO:tensorflow:loss = 0.40615466, step = 21200 (0.157 sec)
# INFO:tensorflow:global_step/sec: 643.543
# INFO:tensorflow:loss = 0.4039778, step = 21300 (0.155 sec)
# INFO:tensorflow:global_step/sec: 641.663
# INFO:tensorflow:loss = 0.4094352, step = 21400 (0.156 sec)
# INFO:tensorflow:global_step/sec: 637.881
# INFO:tensorflow:loss = 0.40315273, step = 21500 (0.157 sec)
# INFO:tensorflow:global_step/sec: 491.391
# INFO:tensorflow:loss = 0.40149492, step = 21600 (0.204 sec)
# INFO:tensorflow:global_step/sec: 343.84
# INFO:tensorflow:loss = 0.40538117, step = 21700 (0.291 sec)
# INFO:tensorflow:global_step/sec: 494.012
# INFO:tensorflow:loss = 0.39771914, step = 21800 (0.202 sec)
# INFO:tensorflow:global_step/sec: 633.47
# INFO:tensorflow:loss = 0.39791602, step = 21900 (0.158 sec)
# INFO:tensorflow:global_step/sec: 639.533
# INFO:tensorflow:loss = 0.3947248, step = 22000 (0.156 sec)
# INFO:tensorflow:global_step/sec: 619.816
# INFO:tensorflow:loss = 0.39180058, step = 22100 (0.161 sec)
# INFO:tensorflow:global_step/sec: 637.041
# INFO:tensorflow:loss = 0.39920378, step = 22200 (0.157 sec)
# INFO:tensorflow:global_step/sec: 645.593
# INFO:tensorflow:loss = 0.39386833, step = 22300 (0.155 sec)
# INFO:tensorflow:global_step/sec: 637.236
# INFO:tensorflow:loss = 0.39117783, step = 22400 (0.157 sec)
# INFO:tensorflow:global_step/sec: 613.831
# INFO:tensorflow:loss = 0.3842371, step = 22500 (0.163 sec)
# INFO:tensorflow:global_step/sec: 615.271
# INFO:tensorflow:loss = 0.38868135, step = 22600 (0.162 sec)
# INFO:tensorflow:global_step/sec: 615.855
# INFO:tensorflow:loss = 0.38257995, step = 22700 (0.162 sec)
# INFO:tensorflow:global_step/sec: 629.422
# INFO:tensorflow:loss = 0.37905943, step = 22800 (0.159 sec)
# INFO:tensorflow:global_step/sec: 644.878
# INFO:tensorflow:loss = 0.38228625, step = 22900 (0.155 sec)
# INFO:tensorflow:global_step/sec: 643.629
# INFO:tensorflow:loss = 0.37902203, step = 23000 (0.155 sec)
# INFO:tensorflow:global_step/sec: 642.365
# INFO:tensorflow:loss = 0.38362652, step = 23100 (0.156 sec)
# INFO:tensorflow:global_step/sec: 646.39
# INFO:tensorflow:loss = 0.3704259, step = 23200 (0.155 sec)
# INFO:tensorflow:global_step/sec: 645.924
# INFO:tensorflow:loss = 0.37488762, step = 23300 (0.155 sec)
# INFO:tensorflow:global_step/sec: 644.704
# INFO:tensorflow:loss = 0.36919665, step = 23400 (0.155 sec)
# INFO:tensorflow:global_step/sec: 640.221
# INFO:tensorflow:loss = 0.37571862, step = 23500 (0.156 sec)
# INFO:tensorflow:global_step/sec: 643.24
# INFO:tensorflow:loss = 0.37091643, step = 23600 (0.155 sec)
# INFO:tensorflow:global_step/sec: 639.713
# INFO:tensorflow:loss = 0.36944395, step = 23700 (0.156 sec)
# INFO:tensorflow:global_step/sec: 634.458
# INFO:tensorflow:loss = 0.3682918, step = 23800 (0.158 sec)
# INFO:tensorflow:global_step/sec: 638.908
# INFO:tensorflow:loss = 0.36921996, step = 23900 (0.157 sec)
# INFO:tensorflow:global_step/sec: 608.532
# INFO:tensorflow:loss = 0.36085108, step = 24000 (0.164 sec)
# INFO:tensorflow:global_step/sec: 644.426
# INFO:tensorflow:loss = 0.3657954, step = 24100 (0.155 sec)
# INFO:tensorflow:global_step/sec: 643.624
# INFO:tensorflow:loss = 0.36267245, step = 24200 (0.155 sec)
# INFO:tensorflow:global_step/sec: 454.802
# INFO:tensorflow:loss = 0.35190636, step = 24300 (0.220 sec)
# INFO:tensorflow:global_step/sec: 484.562
# INFO:tensorflow:loss = 0.36056632, step = 24400 (0.206 sec)
# INFO:tensorflow:global_step/sec: 630.617
# INFO:tensorflow:loss = 0.35355395, step = 24500 (0.159 sec)
# INFO:tensorflow:global_step/sec: 644.882
# INFO:tensorflow:loss = 0.35651138, step = 24600 (0.155 sec)
# INFO:tensorflow:global_step/sec: 644.205
# INFO:tensorflow:loss = 0.35466212, step = 24700 (0.155 sec)
# INFO:tensorflow:global_step/sec: 644.4
# INFO:tensorflow:loss = 0.35094494, step = 24800 (0.155 sec)
# INFO:tensorflow:global_step/sec: 635.551
# INFO:tensorflow:loss = 0.34654278, step = 24900 (0.157 sec)
# INFO:tensorflow:global_step/sec: 640.448
# INFO:tensorflow:loss = 0.35213006, step = 25000 (0.156 sec)
# INFO:tensorflow:global_step/sec: 639.999
# INFO:tensorflow:loss = 0.34820187, step = 25100 (0.156 sec)
# INFO:tensorflow:global_step/sec: 637.828
# INFO:tensorflow:loss = 0.34836006, step = 25200 (0.157 sec)
# INFO:tensorflow:global_step/sec: 636.502
# INFO:tensorflow:loss = 0.3401347, step = 25300 (0.157 sec)
# INFO:tensorflow:global_step/sec: 641.005
# INFO:tensorflow:loss = 0.34454966, step = 25400 (0.156 sec)
# INFO:tensorflow:global_step/sec: 643.231
# INFO:tensorflow:loss = 0.33822644, step = 25500 (0.156 sec)
# INFO:tensorflow:global_step/sec: 640.832
# INFO:tensorflow:loss = 0.33070618, step = 25600 (0.156 sec)
# INFO:tensorflow:global_step/sec: 643.485
# INFO:tensorflow:loss = 0.33746606, step = 25700 (0.155 sec)
# INFO:tensorflow:global_step/sec: 636.675
# INFO:tensorflow:loss = 0.33980075, step = 25800 (0.157 sec)
# INFO:tensorflow:global_step/sec: 635.199
# INFO:tensorflow:loss = 0.33341414, step = 25900 (0.157 sec)
# INFO:tensorflow:global_step/sec: 639.897
# INFO:tensorflow:loss = 0.33583736, step = 26000 (0.156 sec)
# INFO:tensorflow:global_step/sec: 638.056
# INFO:tensorflow:loss = 0.33143055, step = 26100 (0.157 sec)
# INFO:tensorflow:global_step/sec: 637.476
# INFO:tensorflow:loss = 0.33314568, step = 26200 (0.157 sec)
# INFO:tensorflow:global_step/sec: 645.356
# INFO:tensorflow:loss = 0.32653785, step = 26300 (0.155 sec)
# INFO:tensorflow:global_step/sec: 638.701
# INFO:tensorflow:loss = 0.332162, step = 26400 (0.156 sec)
# INFO:tensorflow:global_step/sec: 636.087
# INFO:tensorflow:loss = 0.32675463, step = 26500 (0.157 sec)
# INFO:tensorflow:global_step/sec: 638.86
# INFO:tensorflow:loss = 0.32477117, step = 26600 (0.156 sec)
# INFO:tensorflow:global_step/sec: 642.863
# INFO:tensorflow:loss = 0.32142064, step = 26700 (0.156 sec)
# INFO:tensorflow:global_step/sec: 631.186
# INFO:tensorflow:loss = 0.3201128, step = 26800 (0.158 sec)
# INFO:tensorflow:global_step/sec: 638.639
# INFO:tensorflow:loss = 0.32248718, step = 26900 (0.157 sec)
# INFO:tensorflow:global_step/sec: 643.335
# INFO:tensorflow:loss = 0.3200676, step = 27000 (0.155 sec)
# INFO:tensorflow:global_step/sec: 643.108
# INFO:tensorflow:loss = 0.32108557, step = 27100 (0.156 sec)
# INFO:tensorflow:global_step/sec: 635.995
# INFO:tensorflow:loss = 0.31783712, step = 27200 (0.157 sec)
# INFO:tensorflow:global_step/sec: 643.795
# INFO:tensorflow:loss = 0.31832153, step = 27300 (0.155 sec)
# INFO:tensorflow:global_step/sec: 648.815
# INFO:tensorflow:loss = 0.31737414, step = 27400 (0.154 sec)
# INFO:tensorflow:global_step/sec: 469.548
# INFO:tensorflow:loss = 0.31427026, step = 27500 (0.213 sec)
# INFO:tensorflow:global_step/sec: 393.105
# INFO:tensorflow:loss = 0.3151209, step = 27600 (0.254 sec)
# INFO:tensorflow:global_step/sec: 629.152
# INFO:tensorflow:loss = 0.30383024, step = 27700 (0.159 sec)
# INFO:tensorflow:global_step/sec: 629.929
# INFO:tensorflow:loss = 0.30743533, step = 27800 (0.159 sec)
# INFO:tensorflow:global_step/sec: 538.173
# INFO:tensorflow:loss = 0.2964417, step = 27900 (0.187 sec)
# INFO:tensorflow:global_step/sec: 363.985
# INFO:tensorflow:loss = 0.29994273, step = 28000 (0.276 sec)
# INFO:tensorflow:global_step/sec: 529.888
# INFO:tensorflow:loss = 0.30535522, step = 28100 (0.186 sec)
# INFO:tensorflow:global_step/sec: 620.829
# INFO:tensorflow:loss = 0.30633754, step = 28200 (0.161 sec)
# INFO:tensorflow:global_step/sec: 626.057
# INFO:tensorflow:loss = 0.30208012, step = 28300 (0.160 sec)
# INFO:tensorflow:global_step/sec: 635.013
# INFO:tensorflow:loss = 0.29982746, step = 28400 (0.158 sec)
# INFO:tensorflow:global_step/sec: 638.529
# INFO:tensorflow:loss = 0.30710495, step = 28500 (0.157 sec)
# INFO:tensorflow:global_step/sec: 643.41
# INFO:tensorflow:loss = 0.2885712, step = 28600 (0.156 sec)
# INFO:tensorflow:global_step/sec: 643.655
# INFO:tensorflow:loss = 0.29938972, step = 28700 (0.155 sec)
# INFO:tensorflow:global_step/sec: 637.179
# INFO:tensorflow:loss = 0.2932111, step = 28800 (0.157 sec)
# INFO:tensorflow:global_step/sec: 620.134
# INFO:tensorflow:loss = 0.29508775, step = 28900 (0.161 sec)
# INFO:tensorflow:global_step/sec: 641.388
# INFO:tensorflow:loss = 0.29474968, step = 29000 (0.156 sec)
# INFO:tensorflow:global_step/sec: 633.28
# INFO:tensorflow:loss = 0.3024102, step = 29100 (0.158 sec)
# INFO:tensorflow:global_step/sec: 637.012
# INFO:tensorflow:loss = 0.2901269, step = 29200 (0.157 sec)
# INFO:tensorflow:global_step/sec: 635.09
# INFO:tensorflow:loss = 0.29002613, step = 29300 (0.157 sec)
# INFO:tensorflow:global_step/sec: 639.988
# INFO:tensorflow:loss = 0.29161364, step = 29400 (0.156 sec)
# INFO:tensorflow:global_step/sec: 646.654
# INFO:tensorflow:loss = 0.287158, step = 29500 (0.155 sec)
# INFO:tensorflow:global_step/sec: 600.864
# INFO:tensorflow:loss = 0.29663908, step = 29600 (0.166 sec)
# INFO:tensorflow:global_step/sec: 598.257
# INFO:tensorflow:loss = 0.282392, step = 29700 (0.167 sec)
# INFO:tensorflow:global_step/sec: 633.216
# INFO:tensorflow:loss = 0.2922778, step = 29800 (0.158 sec)
# INFO:tensorflow:global_step/sec: 636.509
# INFO:tensorflow:loss = 0.286132, step = 29900 (0.157 sec)
# INFO:tensorflow:global_step/sec: 642.664
# INFO:tensorflow:loss = 0.28342134, step = 30000 (0.155 sec)
# INFO:tensorflow:global_step/sec: 631.318
# INFO:tensorflow:loss = 0.27979434, step = 30100 (0.158 sec)
# INFO:tensorflow:global_step/sec: 632.127
# INFO:tensorflow:loss = 0.2819649, step = 30200 (0.158 sec)
# INFO:tensorflow:global_step/sec: 633.983
# INFO:tensorflow:loss = 0.2782929, step = 30300 (0.158 sec)
# INFO:tensorflow:global_step/sec: 639.317
# INFO:tensorflow:loss = 0.27954394, step = 30400 (0.156 sec)
# INFO:tensorflow:global_step/sec: 597.318
# INFO:tensorflow:loss = 0.27572358, step = 30500 (0.167 sec)
# INFO:tensorflow:global_step/sec: 631.9
# INFO:tensorflow:loss = 0.2903606, step = 30600 (0.158 sec)
# INFO:tensorflow:global_step/sec: 642.851
# INFO:tensorflow:loss = 0.27647704, step = 30700 (0.156 sec)
# INFO:tensorflow:global_step/sec: 631.78
# INFO:tensorflow:loss = 0.27316087, step = 30800 (0.158 sec)
# INFO:tensorflow:global_step/sec: 630.044
# INFO:tensorflow:loss = 0.2639146, step = 30900 (0.159 sec)
# INFO:tensorflow:global_step/sec: 630.411
# INFO:tensorflow:loss = 0.26970613, step = 31000 (0.159 sec)
# INFO:tensorflow:global_step/sec: 628.361
# INFO:tensorflow:loss = 0.27029434, step = 31100 (0.159 sec)
# INFO:tensorflow:global_step/sec: 632.372
# INFO:tensorflow:loss = 0.26276484, step = 31200 (0.158 sec)
# INFO:tensorflow:global_step/sec: 636.852
# INFO:tensorflow:loss = 0.2740353, step = 31300 (0.157 sec)
# INFO:tensorflow:global_step/sec: 633.212
# INFO:tensorflow:loss = 0.2710727, step = 31400 (0.158 sec)
# INFO:tensorflow:global_step/sec: 639.075
# INFO:tensorflow:loss = 0.2682001, step = 31500 (0.156 sec)
# INFO:tensorflow:global_step/sec: 640.685
# INFO:tensorflow:loss = 0.26922217, step = 31600 (0.156 sec)
# INFO:tensorflow:global_step/sec: 385.187
# INFO:tensorflow:loss = 0.2674799, step = 31700 (0.261 sec)
# INFO:tensorflow:global_step/sec: 537.591
# INFO:tensorflow:loss = 0.25593483, step = 31800 (0.185 sec)
# INFO:tensorflow:global_step/sec: 631.265
# INFO:tensorflow:loss = 0.2562355, step = 31900 (0.158 sec)
# INFO:tensorflow:global_step/sec: 632.948
# INFO:tensorflow:loss = 0.2598152, step = 32000 (0.158 sec)
# INFO:tensorflow:global_step/sec: 629.67
# INFO:tensorflow:loss = 0.2632861, step = 32100 (0.159 sec)
# INFO:tensorflow:global_step/sec: 583.417
# INFO:tensorflow:loss = 0.26118654, step = 32200 (0.171 sec)
# INFO:tensorflow:global_step/sec: 640.094
# INFO:tensorflow:loss = 0.2601784, step = 32300 (0.156 sec)
# INFO:tensorflow:global_step/sec: 639.778
# INFO:tensorflow:loss = 0.25414026, step = 32400 (0.156 sec)
# INFO:tensorflow:global_step/sec: 633.674
# INFO:tensorflow:loss = 0.25432718, step = 32500 (0.158 sec)
# INFO:tensorflow:global_step/sec: 638.284
# INFO:tensorflow:loss = 0.25454327, step = 32600 (0.157 sec)
# INFO:tensorflow:global_step/sec: 639.251
# INFO:tensorflow:loss = 0.25600976, step = 32700 (0.157 sec)
# INFO:tensorflow:global_step/sec: 638.79
# INFO:tensorflow:loss = 0.2455562, step = 32800 (0.156 sec)
# INFO:tensorflow:global_step/sec: 633.725
# INFO:tensorflow:loss = 0.25171962, step = 32900 (0.158 sec)
# INFO:tensorflow:global_step/sec: 626.144
# INFO:tensorflow:loss = 0.25325122, step = 33000 (0.160 sec)
# INFO:tensorflow:global_step/sec: 631.556
# INFO:tensorflow:loss = 0.25394082, step = 33100 (0.158 sec)
# INFO:tensorflow:global_step/sec: 639.091
# INFO:tensorflow:loss = 0.2529012, step = 33200 (0.156 sec)
# INFO:tensorflow:global_step/sec: 642.207
# INFO:tensorflow:loss = 0.2489064, step = 33300 (0.156 sec)
# INFO:tensorflow:global_step/sec: 641.183
# INFO:tensorflow:loss = 0.24195862, step = 33400 (0.156 sec)
# INFO:tensorflow:global_step/sec: 639.681
# INFO:tensorflow:loss = 0.24473919, step = 33500 (0.156 sec)
# INFO:tensorflow:global_step/sec: 646.165
# INFO:tensorflow:loss = 0.24449198, step = 33600 (0.155 sec)
# INFO:tensorflow:global_step/sec: 471.896
# INFO:tensorflow:loss = 0.24767222, step = 33700 (0.212 sec)
# INFO:tensorflow:global_step/sec: 397.81
# INFO:tensorflow:loss = 0.24342546, step = 33800 (0.251 sec)
# INFO:tensorflow:global_step/sec: 374.252
# INFO:tensorflow:loss = 0.24689865, step = 33900 (0.268 sec)
# INFO:tensorflow:global_step/sec: 520.192
# INFO:tensorflow:loss = 0.24580282, step = 34000 (0.191 sec)
# INFO:tensorflow:global_step/sec: 635.97
# INFO:tensorflow:loss = 0.2469873, step = 34100 (0.157 sec)
# INFO:tensorflow:global_step/sec: 638.187
# INFO:tensorflow:loss = 0.24363202, step = 34200 (0.157 sec)
# INFO:tensorflow:global_step/sec: 612.411
# INFO:tensorflow:loss = 0.23918855, step = 34300 (0.163 sec)
# INFO:tensorflow:global_step/sec: 624.489
# INFO:tensorflow:loss = 0.24264067, step = 34400 (0.160 sec)
# INFO:tensorflow:global_step/sec: 635.614
# INFO:tensorflow:loss = 0.23948209, step = 34500 (0.157 sec)
# INFO:tensorflow:global_step/sec: 629.918
# INFO:tensorflow:loss = 0.2356423, step = 34600 (0.159 sec)
# INFO:tensorflow:global_step/sec: 628.697
# INFO:tensorflow:loss = 0.23279278, step = 34700 (0.159 sec)
# INFO:tensorflow:global_step/sec: 632.127
# INFO:tensorflow:loss = 0.2342717, step = 34800 (0.158 sec)
# INFO:tensorflow:global_step/sec: 605.048
# INFO:tensorflow:loss = 0.2309361, step = 34900 (0.165 sec)
# INFO:tensorflow:global_step/sec: 610.105
# INFO:tensorflow:loss = 0.23141712, step = 35000 (0.164 sec)
# INFO:tensorflow:global_step/sec: 607.327
# INFO:tensorflow:loss = 0.23499228, step = 35100 (0.165 sec)
# INFO:tensorflow:global_step/sec: 636.355
# INFO:tensorflow:loss = 0.23323467, step = 35200 (0.157 sec)
# INFO:tensorflow:global_step/sec: 636.822
# INFO:tensorflow:loss = 0.22989461, step = 35300 (0.157 sec)
# INFO:tensorflow:global_step/sec: 630.743
# INFO:tensorflow:loss = 0.222451, step = 35400 (0.159 sec)
# INFO:tensorflow:global_step/sec: 638.036
# INFO:tensorflow:loss = 0.22765088, step = 35500 (0.157 sec)
# INFO:tensorflow:global_step/sec: 636.318
# INFO:tensorflow:loss = 0.22908223, step = 35600 (0.157 sec)
# INFO:tensorflow:global_step/sec: 636.501
# INFO:tensorflow:loss = 0.22171497, step = 35700 (0.157 sec)
# INFO:tensorflow:global_step/sec: 639.988
# INFO:tensorflow:loss = 0.22749206, step = 35800 (0.156 sec)
# INFO:tensorflow:global_step/sec: 643.057
# INFO:tensorflow:loss = 0.22556123, step = 35900 (0.156 sec)
# INFO:tensorflow:global_step/sec: 649.385
# INFO:tensorflow:loss = 0.22870229, step = 36000 (0.154 sec)
# INFO:tensorflow:global_step/sec: 634.469
# INFO:tensorflow:loss = 0.22290714, step = 36100 (0.158 sec)
# INFO:tensorflow:global_step/sec: 612.179
# INFO:tensorflow:loss = 0.22674395, step = 36200 (0.163 sec)
# INFO:tensorflow:global_step/sec: 636.813
# INFO:tensorflow:loss = 0.22704747, step = 36300 (0.157 sec)
# INFO:tensorflow:global_step/sec: 641.989
# INFO:tensorflow:loss = 0.22632521, step = 36400 (0.156 sec)
# INFO:tensorflow:global_step/sec: 638.961
# INFO:tensorflow:loss = 0.23044679, step = 36500 (0.157 sec)
# INFO:tensorflow:global_step/sec: 641.845
# INFO:tensorflow:loss = 0.22946694, step = 36600 (0.156 sec)
# INFO:tensorflow:global_step/sec: 643.273
# INFO:tensorflow:loss = 0.22269091, step = 36700 (0.155 sec)
# INFO:tensorflow:global_step/sec: 643.769
# INFO:tensorflow:loss = 0.21614277, step = 36800 (0.155 sec)
# INFO:tensorflow:global_step/sec: 637.747
# INFO:tensorflow:loss = 0.22189721, step = 36900 (0.157 sec)
# INFO:tensorflow:global_step/sec: 600.064
# INFO:tensorflow:loss = 0.22370146, step = 37000 (0.167 sec)
# INFO:tensorflow:global_step/sec: 645.036
# INFO:tensorflow:loss = 0.21277139, step = 37100 (0.155 sec)
# INFO:tensorflow:global_step/sec: 635.198
# INFO:tensorflow:loss = 0.21557261, step = 37200 (0.158 sec)
# INFO:tensorflow:global_step/sec: 636.841
# INFO:tensorflow:loss = 0.21573678, step = 37300 (0.157 sec)
# INFO:tensorflow:global_step/sec: 637.817
# INFO:tensorflow:loss = 0.21963699, step = 37400 (0.157 sec)
# INFO:tensorflow:global_step/sec: 640.135
# INFO:tensorflow:loss = 0.21836299, step = 37500 (0.156 sec)
# INFO:tensorflow:global_step/sec: 640.75
# INFO:tensorflow:loss = 0.21923205, step = 37600 (0.156 sec)
# INFO:tensorflow:global_step/sec: 618.683
# INFO:tensorflow:loss = 0.21712479, step = 37700 (0.162 sec)
# INFO:tensorflow:global_step/sec: 603.362
# INFO:tensorflow:loss = 0.21398017, step = 37800 (0.165 sec)
# INFO:tensorflow:global_step/sec: 590.849
# INFO:tensorflow:loss = 0.22037613, step = 37900 (0.169 sec)
# INFO:tensorflow:global_step/sec: 644.243
# INFO:tensorflow:loss = 0.21783075, step = 38000 (0.155 sec)
# INFO:tensorflow:global_step/sec: 637.457
# INFO:tensorflow:loss = 0.20782778, step = 38100 (0.157 sec)
# INFO:tensorflow:global_step/sec: 639.022
# INFO:tensorflow:loss = 0.2094023, step = 38200 (0.157 sec)
# INFO:tensorflow:global_step/sec: 642.654
# INFO:tensorflow:loss = 0.20490904, step = 38300 (0.155 sec)
# INFO:tensorflow:global_step/sec: 640.997
# INFO:tensorflow:loss = 0.21181399, step = 38400 (0.156 sec)
# INFO:tensorflow:global_step/sec: 641.849
# INFO:tensorflow:loss = 0.20279975, step = 38500 (0.156 sec)
# INFO:tensorflow:global_step/sec: 638.04
# INFO:tensorflow:loss = 0.21179524, step = 38600 (0.157 sec)
# INFO:tensorflow:global_step/sec: 644.482
# INFO:tensorflow:loss = 0.20131657, step = 38700 (0.155 sec)
# INFO:tensorflow:global_step/sec: 639.813
# INFO:tensorflow:loss = 0.19828162, step = 38800 (0.156 sec)
# INFO:tensorflow:global_step/sec: 644.45
# INFO:tensorflow:loss = 0.20279807, step = 38900 (0.155 sec)
# INFO:tensorflow:global_step/sec: 636.254
# INFO:tensorflow:loss = 0.20841087, step = 39000 (0.157 sec)
# INFO:tensorflow:global_step/sec: 627.359
# INFO:tensorflow:loss = 0.20529094, step = 39100 (0.159 sec)
# INFO:tensorflow:global_step/sec: 628.667
# INFO:tensorflow:loss = 0.20131093, step = 39200 (0.159 sec)
# INFO:tensorflow:global_step/sec: 643.748
# INFO:tensorflow:loss = 0.20763303, step = 39300 (0.156 sec)
# INFO:tensorflow:global_step/sec: 638.178
# INFO:tensorflow:loss = 0.20527229, step = 39400 (0.157 sec)
# INFO:tensorflow:global_step/sec: 634.587
# INFO:tensorflow:loss = 0.19916102, step = 39500 (0.157 sec)
# INFO:tensorflow:global_step/sec: 625.9
# INFO:tensorflow:loss = 0.19716679, step = 39600 (0.160 sec)
# INFO:tensorflow:global_step/sec: 634.82
# INFO:tensorflow:loss = 0.196231, step = 39700 (0.157 sec)
# INFO:tensorflow:global_step/sec: 644.675
# INFO:tensorflow:loss = 0.20191148, step = 39800 (0.155 sec)
# INFO:tensorflow:global_step/sec: 643.716
# INFO:tensorflow:loss = 0.1984882, step = 39900 (0.155 sec)
# INFO:tensorflow:global_step/sec: 641.244
# INFO:tensorflow:loss = 0.1986021, step = 40000 (0.156 sec)
# INFO:tensorflow:global_step/sec: 636.092
# INFO:tensorflow:loss = 0.19973868, step = 40100 (0.157 sec)
# INFO:tensorflow:global_step/sec: 640.615
# INFO:tensorflow:loss = 0.19171333, step = 40200 (0.156 sec)
# INFO:tensorflow:global_step/sec: 638.33
# INFO:tensorflow:loss = 0.19920269, step = 40300 (0.157 sec)
# INFO:tensorflow:global_step/sec: 636.878
# INFO:tensorflow:loss = 0.19377543, step = 40400 (0.157 sec)
# INFO:tensorflow:global_step/sec: 649.359
# INFO:tensorflow:loss = 0.19265261, step = 40500 (0.154 sec)
# INFO:tensorflow:global_step/sec: 559.259
# INFO:tensorflow:loss = 0.19661248, step = 40600 (0.180 sec)
# INFO:tensorflow:global_step/sec: 348.103
# INFO:tensorflow:loss = 0.19506669, step = 40700 (0.287 sec)
# INFO:tensorflow:global_step/sec: 474.215
# INFO:tensorflow:loss = 0.18658863, step = 40800 (0.211 sec)
# INFO:tensorflow:global_step/sec: 368.157
# INFO:tensorflow:loss = 0.19740613, step = 40900 (0.271 sec)
# INFO:tensorflow:global_step/sec: 491.894
# INFO:tensorflow:loss = 0.19405499, step = 41000 (0.203 sec)
# INFO:tensorflow:global_step/sec: 605.158
# INFO:tensorflow:loss = 0.19352537, step = 41100 (0.165 sec)
# INFO:tensorflow:global_step/sec: 508.929
# INFO:tensorflow:loss = 0.19272192, step = 41200 (0.197 sec)
# INFO:tensorflow:global_step/sec: 374.983
# INFO:tensorflow:loss = 0.19201714, step = 41300 (0.266 sec)
# INFO:tensorflow:global_step/sec: 601.342
# INFO:tensorflow:loss = 0.19329965, step = 41400 (0.167 sec)
# INFO:tensorflow:global_step/sec: 621.149
# INFO:tensorflow:loss = 0.18862015, step = 41500 (0.161 sec)
# INFO:tensorflow:global_step/sec: 621.102
# INFO:tensorflow:loss = 0.19188997, step = 41600 (0.161 sec)
# INFO:tensorflow:global_step/sec: 624.637
# INFO:tensorflow:loss = 0.19690491, step = 41700 (0.161 sec)
# INFO:tensorflow:global_step/sec: 623.795
# INFO:tensorflow:loss = 0.19860461, step = 41800 (0.160 sec)
# INFO:tensorflow:global_step/sec: 619.468
# INFO:tensorflow:loss = 0.18731226, step = 41900 (0.161 sec)
# INFO:tensorflow:global_step/sec: 620.91
# INFO:tensorflow:loss = 0.18611448, step = 42000 (0.161 sec)
# INFO:tensorflow:global_step/sec: 621.678
# INFO:tensorflow:loss = 0.19204307, step = 42100 (0.161 sec)
# INFO:tensorflow:global_step/sec: 610.348
# INFO:tensorflow:loss = 0.18769446, step = 42200 (0.164 sec)
# INFO:tensorflow:global_step/sec: 624.442
# INFO:tensorflow:loss = 0.19292039, step = 42300 (0.160 sec)
# INFO:tensorflow:global_step/sec: 622.797
# INFO:tensorflow:loss = 0.17874181, step = 42400 (0.160 sec)
# INFO:tensorflow:global_step/sec: 626.692
# INFO:tensorflow:loss = 0.18374786, step = 42500 (0.159 sec)
# INFO:tensorflow:global_step/sec: 621.354
# INFO:tensorflow:loss = 0.17729501, step = 42600 (0.161 sec)
# INFO:tensorflow:global_step/sec: 618.452
# INFO:tensorflow:loss = 0.18428764, step = 42700 (0.161 sec)
# INFO:tensorflow:global_step/sec: 604.424
# INFO:tensorflow:loss = 0.18248062, step = 42800 (0.165 sec)
# INFO:tensorflow:global_step/sec: 625.266
# INFO:tensorflow:loss = 0.180063, step = 42900 (0.160 sec)
# INFO:tensorflow:global_step/sec: 627.462
# INFO:tensorflow:loss = 0.17572694, step = 43000 (0.159 sec)
# INFO:tensorflow:global_step/sec: 628.84
# INFO:tensorflow:loss = 0.18247229, step = 43100 (0.159 sec)
# INFO:tensorflow:global_step/sec: 624.848
# INFO:tensorflow:loss = 0.18139443, step = 43200 (0.160 sec)
# INFO:tensorflow:global_step/sec: 623.569
# INFO:tensorflow:loss = 0.18537493, step = 43300 (0.160 sec)
# INFO:tensorflow:global_step/sec: 624.151
# INFO:tensorflow:loss = 0.17869568, step = 43400 (0.160 sec)
# INFO:tensorflow:global_step/sec: 613.745
# INFO:tensorflow:loss = 0.17685652, step = 43500 (0.163 sec)
# INFO:tensorflow:global_step/sec: 623.014
# INFO:tensorflow:loss = 0.18288219, step = 43600 (0.161 sec)
# INFO:tensorflow:global_step/sec: 616.972
# INFO:tensorflow:loss = 0.1790452, step = 43700 (0.162 sec)
# INFO:tensorflow:global_step/sec: 619.118
# INFO:tensorflow:loss = 0.18098761, step = 43800 (0.162 sec)
# INFO:tensorflow:global_step/sec: 624.586
# INFO:tensorflow:loss = 0.17667796, step = 43900 (0.160 sec)
# INFO:tensorflow:global_step/sec: 624.099
# INFO:tensorflow:loss = 0.17602828, step = 44000 (0.160 sec)
# INFO:tensorflow:global_step/sec: 623.929
# INFO:tensorflow:loss = 0.17063244, step = 44100 (0.160 sec)
# INFO:tensorflow:global_step/sec: 624.305
# INFO:tensorflow:loss = 0.17949137, step = 44200 (0.160 sec)
# INFO:tensorflow:global_step/sec: 621.303
# INFO:tensorflow:loss = 0.18068507, step = 44300 (0.161 sec)
# INFO:tensorflow:global_step/sec: 609.508
# INFO:tensorflow:loss = 0.17990191, step = 44400 (0.164 sec)
# INFO:tensorflow:global_step/sec: 615.505
# INFO:tensorflow:loss = 0.17660636, step = 44500 (0.162 sec)
# INFO:tensorflow:global_step/sec: 623.827
# INFO:tensorflow:loss = 0.18089509, step = 44600 (0.160 sec)
# INFO:tensorflow:global_step/sec: 617.246
# INFO:tensorflow:loss = 0.17192289, step = 44700 (0.162 sec)
# INFO:tensorflow:global_step/sec: 613.776
# INFO:tensorflow:loss = 0.18374184, step = 44800 (0.163 sec)
# INFO:tensorflow:global_step/sec: 623.118
# INFO:tensorflow:loss = 0.17211483, step = 44900 (0.160 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 45000...
# INFO:tensorflow:Saving checkpoints for 45000 into /var/folders/01/4d70j3nn55z71b4011q5p56r0000gn/T/tmp21oq8rrp/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 45000...
# INFO:tensorflow:Loss for final step: 0.16535574.

# %% [markdown]
# El único parámetro que no hemos visto hasta ahora es el parámetro steps. Este parámetro le dice al clasificador que actualice el valor de los parámetros libres 5000 veces, cuanto mayor sea el número más datos verá la red.

# %% [markdown]
# ### Evaluación
#
# Evaluamos nuestro modelo:

# %%
eval_result = classifier.evaluate(
    input_fn=lambda: input_fn(test, test_y, training=False))

print('\nTest set accuracy: {accuracy:0.3f}\n'.format(**eval_result))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-04-15T21:38:46Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/01/4d70j3nn55z71b4011q5p56r0000gn/T/tmp21oq8rrp/model.ckpt-45000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.22091s
# INFO:tensorflow:Finished evaluation at 2021-04-15-21:38:47
# INFO:tensorflow:Saving dict for global step 45000: accuracy = 1.0, average_loss = 0.18637206, global_step = 45000, loss = 0.18637206
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 45000: /var/folders/01/4d70j3nn55z71b4011q5p56r0000gn/T/tmp21oq8rrp/model.ckpt-45000
#
# Test set accuracy: 1.000

# %% [markdown]
# Como podemos ver, ahora no hemos especificado el número de pasos. Esto se debe a que durante la evaluación el modelo símplemente va a ver todos los datos de test una sola vez para poder clasificarlos.

# %% [markdown]
# ### Predicciones
#
# Una vez entrenado y evaluado el modelo, el último paso que tenemos que hacer es utilizar este modelo para realizar predicciones. A continuación tenemos un pequeño script que nos permite introducir las características de una flor y ver su predicción:

# %%
def input_fn(features, batch_size=256):
    # Transforma las entradas a un Dataset sin etiquetas
    return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_size)

features = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']
predict = {}

print("Por favor, introduce valores numéricos de tipo float64 (los números deben ser decimales).")
for feature in features:
  valid = True
  while valid: 
    val = input(feature + ": ")
    if not val.isdigit(): valid = False

  predict[feature] = [float(val)]

predictions = classifier.predict(input_fn=lambda: input_fn(predict))
for pred_dict in predictions:
    class_id = pred_dict['class_ids'][0]
    probability = pred_dict['probabilities'][class_id]

    print('La predicción es: "{}" ({:.1f}%)'.format(
        SPECIES[class_id], 100 * probability))
# Out:
# Por favor, introduce valores numéricos de tipo float64 (los números deben ser decimales).
# SepalLength:  5.1
# SepalWidth:  3.3
# PetalLength:  1.7
# PetalWidth:  0.5
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/01/4d70j3nn55z71b4011q5p56r0000gn/T/tmp21oq8rrp/model.ckpt-45000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# La predicción es: "Setosa" (88.8%)

# %%
# Estos son unos cuantos ejemplos que podríamos probar en el script de arriba:
expected = ['Setosa', 'Versicolor', 'Virginica']
predict_x = {
    'SepalLength': [5.1, 5.9, 6.9],
    'SepalWidth': [3.3, 3.0, 3.1],
    'PetalLength': [1.7, 4.2, 5.4],
    'PetalWidth': [0.5, 1.5, 2.1],
}
